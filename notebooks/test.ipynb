# %%
import os
from pathlib import Path
import sys
current_dir = Path(os.getcwd())
sys.path.insert(0, str(current_dir.parent))

# %%
# !pip install pydantic-settings
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %%
from config.env_var import conf_settings
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from config.env_var import conf_settings
#
# File ~/projects/sme_airflow_docker/config/env_var.py:22
#      18         env_file_encoding = "utf-8"
#      19         extra = "ignore"
# ---> 22 conf_settings = EnvVarsSettings()
#
# ...

# %%
conf_settings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 conf_settings
#
# NameError: name 'conf_settings' is not defined

# %%
import re
ddl_query = """CREATE TABLE IF NOT EXISTS {FULL_TABLE_NAME} (
	id serial4 NOT NULL,
	created_date timestamp NULL,
	updated_date timestamp NULL,
	CONSTRAINT sink_table_pkey PRIMARY KEY (id)
);"""
ddl_query = re.sub(r'CONSTRAINT\s+\w+\s+', '', ddl_query)

# %%
print(ddl_query)
# Out:
# CREATE TABLE IF NOT EXISTS {FULL_TABLE_NAME} (
# 	id serial4 NOT NULL,
# 	created_date timestamp NULL,
# 	updated_date timestamp NULL,
# 	PRIMARY KEY (id)
# );

# %%
import datetime
t= datetime.datetime(2025, 12, 4, 4, 19, 43, 411619, tzinfo=datetime.timezone.utc)

# %%
datetime.datetime(2025, 12, 8, 5, 38, 7, 162535, tzinfo=datetime.timezone.utc).isoformat()
# Out:
# '2025-12-08T05:38:07.162535+00:00'

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 12, 8, 13, 5, 37, 592798)
